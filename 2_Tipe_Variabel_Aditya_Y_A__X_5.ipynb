# %% [markdown]
# <a href="https://colab.research.google.com/github/adityayusufalfarizqi/KKA-X-Semester-1/blob/main/2_Tipe_Variabel_Aditya_Y_A__X_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Aditya Yusuf Alfarizqi
#
# Kelas: X.5
#
# No. Absen: 2

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print("adityayusufalfarizqi.2025@gmail.com")
print("adityayusufalfarizqi.2025@gmail.com")
print("adityayusufalfarizqi.2025@gmail.com")
# Out:
# adityayusufalfarizqi.2025@gmail.com
# adityayusufalfarizqi.2025@gmail.com
# adityayusufalfarizqi.2025@gmail.com

# %%
email_user_1="adityayusufalfarizqi.2025@gmail.com"
print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# adityayusufalfarizqi.2025@gmail.com
# adityayusufalfarizqi.2025@gmail.com
# adityayusufalfarizqi.2025@gmail.com

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
email user 2="upinaruffin@gmail.com"
print(email user 2)
# Out:
#   File "/tmp/ipython-input-2560366294.py", line 1
#     email user 2="upinaruffin@gmail.com"
#           ^
# SyntaxError: invalid syntax

# %%
#Hanya boleh menggunakan angka, huruf, dan underscore
emailuser2="upinaruffin@gmail.com"
print(emailuser2)
# Out:
# upinaruffin@gmail.com

# %%
email_user_2="ipinariffin@gmail.com"
print(email_user_2)
# Out:
# ipinariffin@gmail.com

# %%
3_email_user="akakroscantik@gmail.com"
print(3_email_user)
# Out:
#   File "/tmp/ipython-input-2679697138.py", line 1
#     3_email_user="akakroscantik@gmail.com"
#      ^
# SyntaxError: invalid decimal literal

# %%
#Tidak boleh didahului oleh angka
email_user_3="akakroscantik@gmail.com"
print(email_user_3)
# Out:
# akakroscantik@gmail.com

# %%
email_user_4="....@gmail.com"
print(email_user_4)
# Out:
# ....@gmail.com

# %%
#Penulisan variabel sensitif terhadap kapital
Email_User_4="OpahTersayang@gmail.com"
print(Email_User_4)
# Out:
# OpahTersayang@gmail.com

# %%
if="cikgumelati@gmail.com"
print(if)
# Out:
#   File "/tmp/ipython-input-86409757.py", line 1
#     if="cikgumelati@gmail.com"
#       ^
# SyntaxError: invalid syntax

# %%
If="cikgumelati@gmail.com"
print(If)
# Out:
# cikgumelati@gmail.com

# %%
print="mailduaseringgit@gmail.com"
print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2481275931.py in <cell line: 0>()
#       1 print="mailduaseringgit@gmail.com"
# ----> 2 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print="mailduaseringgit@gmail.com"
print(Print)
# Out:
# mailduaseringgit@gmail.com

# %%
#Harus deskriptif meski tidak error
_="kedaimuthu@gmail.com"
print(_)
# Out:
# kedaimuthu@gmail.com

# %%
_="kedaiahtong@gmail.com"
print(_)
# Out:
# kedaiahtong@gmail.com

# %%
print(_)
# Out:
# kedaiahtong@gmail.com

# %%
print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3925571382.py in <cell line: 0>()
# ----> 1 print(i)
#
# NameError: name 'i' is not defined

# %% [markdown]
# #Assignment

# %% [markdown]
# #Single Assignment

# %%
nama_siswa_2="Daphne"
nama_siswa_3="Farel"
print(nama_siswa_2)
print(nama_siswa_3)
# Out:
# Daphne
# Farel

# %% [markdown]
# #Multiple Assignment

# %%
nama_siswa_4, nama_siswa_5="Sada", "Selo"
print(nama_siswa_4)
print(nama_siswa_5)
# Out:
# Sada
# Selo

# %% [markdown]
# #Chain Assignment

# %%
nilai_afa=nilai_favian=100
print(nilai_afa)
print(nilai_favian)
# Out:
# 100
# 100

# %% [markdown]
# #Aritmatika

# %%
#Operand tanpa disimpan dalam variabel
print(5000*3)
# Out:
# 15000

# %%
#Simpan operand ke dalam variabel
harga_kojek=6000
banyak_porsi=3
print(harga_kojek*banyak_porsi)
# Out:
# 18000

# %%
#Simpan hasil operasi ke dalam variabel
harga_total_kojek=3000*3
print(harga_total_kojek)
# Out:
# 9000

# %%
#Simpan nilai operand dan hasil operasi ke dalam variabel
harga_cilok=10000
jumlah_porsi_cilok=5
harga_total_cilok=harga_cilok*jumlah_porsi_cilok
print(harga_total_cilok)
# Out:
# 50000

# %%
uang_yang_diterima=100000
uang_kembalian=uang_yang_diterima-harga_total_cilok
print(uang_kembalian)
# Out:
# 50000

# %% [markdown]
# #Jenis Tipe Variabel pada Phyton

# %%
#Float
x=17.5
print(x)
type(x)
# Out:
# 17.5
# float

# %%
#Integer
y=8
print(y)
type(y)
# Out:
# 8
# int

# %%
#String
z="adit"
print(z)
type(z)
# Out:
# adit
# str

# %%
#Boolean
p=True
print(p)
type(p)
# Out:
# True
# bool

# %%
r=-2.5
print(r)
type(r)
# Out:
# -2.5
# float

# %%
s=5.1
print(s)
type(s)
# Out:
# 5.1
# float

# %%
k='%7akh3.'
print(k)
type(k)
# Out:
# %7akh3.
# str

# %% [markdown]
# #Mengubah Tipe Data

# %%
a=25
print(a)
type(a)
# Out:
# 25
# int

# %%
a=float(a)
print(a)
type(a)
# Out:
# 25.0
# float

# %%
a=str(a)
print(a)
type(a)
# Out:
# 25.0
# str

# %%
a=bool(a)
print(a)
type(a)
# Out:
# True
# bool

# %%
b=True
print(b)
type(b)
# Out:
# True
# bool

# %%
b=int(b)
print(b)
type(b)
# Out:
# 1
# int

# %%
b=float(b)
print(b)
type(b)
# Out:
# 1.0
# float

# %%
b=str(b)
print(b)
type(b)
# Out:
# 1.0
# str

# %%
c=False
print(c)
type(c)
# Out:
# False
# bool

# %%
c=float(c)
print(c)
type(c)
# Out:
# 0.0
# float

# %%
c=int(c)
print(c)
type(c)
# Out:
# 0
# int

# %%
c=str(c)
print(c)
type(c)
# Out:
# 0
# str

# %% [markdown]
# #Operator Perbandingan

# %%
print(6>0)
# Out:
# True

# %%
print(7>9)
# Out:
# False

# %%
print(8<9)
# Out:
# True

# %%
print(8<4)
# Out:
# False

# %%
print(5>=5)
# Out:
# True

# %%
print(6>=5)
# Out:
# True

# %%
print(3==2)
# Out:
# False

# %%
print(3==3)
# Out:
# True

# %%
print(5!=5)
# Out:
# False

# %%
a=8
b=9
print(b<a)
# Out:
# False

# %%
print(b<8)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print(7!=8 and 8>2)
# Out:
# True

# %%
print(7==8 and 8>2)
# Out:
# False

# %%
print(7==8 or 8>2)
# Out:
# True

# %%
print(not 7==8)
# Out:
# True

# %%
m=10
n=20
p=30
print(m<n and p>m)
# Out:
# True

# %%
print(not (m<n or p>m))
# Out:
# False
