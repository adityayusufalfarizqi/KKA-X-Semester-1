# %% [markdown]
# <a href="https://colab.research.google.com/github/adityayusufalfarizqi/KKA-X-Semester-1/blob/main/Aplikasi_Bangun_Kerucut_Aditya_Yusuf_Alfarizqi_X_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama Kelompok: Capybara bobo
#
# Nama: Aditya Yusuf Alfarizqi
#
# Kelas: X-5
#
# No. Absen: 2

# %%
#Program menghitung volume kerucut

#Meminta input dari pengguna
jari_jari_alas = float(input("Masukkan jari-jari alas kerucut(cm):"))
tinggi = float(input("Masukkan tinggi kerucut(cm):"))

#Menghitung volume
volume = (1/3) * (22/7) * jari_jari_alas**2 * tinggi

#Menampilkan hasil
print(f"Volume kerucut adalah: {volume} cm^3.")
